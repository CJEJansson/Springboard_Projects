# %%
#Import Libraries
import numpy as np
import pandas as pd

# %% [markdown]
# After investigation of the "Name" column, in the attempt to address Null values, it was determined that just because an animal had a value in the name column, did not mean that the animal actually had a name. Due to the size and extent of the problem, name's were manually cleaned using excel. Some of the following are examples of name entries that were found and were replaced with a null:
#     - Lost Dog
#     - Cute Puppies
#     - Boy
#     - Girl
#     - Micellaneous breed names
#     - No Name Yet
#     - Please Name Me
#     - "Save me or I'll Die"
#     - Urgent home needed
#     - Puppy
#     - Various descriptions of puppies (happy puppy, big eyes, sad puppy,
#       bouncy puppy, etc.)
#
# The names that are missing are left as null values.

# %% [markdown]
# A similar activity was performed after additional investigation of the "description" column. The following values are exaples of data that was removed and replaced with null vales:
#
#     - #NAME?
#     - URGENT!!
#     - ‰ªñÊòØË¢ and variations of webding like characters
#     - "..." and variations on quantity of dots
#
#
#
# These files were saved under different names, and will be used for the rest of the data wrangling in place of the original files 'train' and 'test'.

# %%
#File Names
breedfile = 'data/breed_labels.csv'
colorfile = 'data/color_labels.csv'
statefile = 'data/state_labels.csv'
testfile = 'data/test/test_clean.csv'
trainfile = 'data/train_clean.csv'

#Import Files
breeds=pd.read_csv(breedfile)
color=pd.read_csv(colorfile)
state=pd.read_csv(statefile)
test_data=pd.read_csv(testfile)
train_data=pd.read_csv(trainfile)

# %%
#Examine Test Data Set
test_data.head()
# Out:
#    Type                       Name  Age  Breed1  Breed2  Gender  Color1  \
# 0     2               Dopey & Grey    8     266     266       1       2
# 1     2                    Chi Chi   36     285     264       2       1
# 2     2                     Sticky    2     265       0       1       6
# 3     1  Dannie & Kass [In Penang]   12     307       0       2       2
# 4     2                    Cuddles   12     265       0       1       2
#
#    Color2  Color3  MaturitySize  ...  Sterilized  Health  Quantity  Fee  \
# 0       6       7             1  ...           2       1         2    0
# 1       4       7             2  ...           1       2         1    0
# 2       7       0             2  ...           2       1         1  200
# 3       5       0             2  ...           1       1         2    0
# 4       3       7             2  ...           1       1         1    0
#
#    State                         RescuerID  VideoAmt  \
# 0  41326  2ece3b2573dcdcebd774e635dca15fd9         0
# 1  41326  2ece3b2573dcdcebd774e635dca15fd9         0
# 2  41326  e59c106e9912fa30c898976278c2e834         0
# 3  41326  e59c106e9912fa30c898976278c2e834         0
# 4  41326  e59c106e9912fa30c898976278c2e834         0
#
#                                          Description      PetID  PhotoAmt
# 0  Dopey Age: 8mths old Male One half of a pair, ...  e2dfc2935         2
# 1  Please note that Chichi has been neutered, the...  f153b465f         1
# 2  Sticky, named such because of his tendency to ...  3c90f3f54         4
# 3  Dannie and Kass are mother and daughter. We en...  e02abc8a3         5
# 4  Extremely cuddly cat, hence the origin of his ...  09f0df7d1         5
#
# [5 rows x 23 columns]

# %%
test_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3972 entries, 0 to 3971
# Data columns (total 23 columns):
# Type            3972 non-null int64
# Name            3149 non-null object
# Age             3972 non-null int64
# Breed1          3972 non-null int64
# Breed2          3972 non-null int64
# Gender          3972 non-null int64
# Color1          3972 non-null int64
# Color2          3972 non-null int64
# Color3          3972 non-null int64
# MaturitySize    3972 non-null int64
# FurLength       3972 non-null int64
# Vaccinated      3972 non-null int64
# Dewormed        3972 non-null int64
# Sterilized      3972 non-null int64
# Health          3972 non-null int64
# Quantity        3972 non-null int64
# Fee             3972 non-null int64
# State           3972 non-null int64
# RescuerID       3972 non-null object
# VideoAmt        3972 non-null int64
# Description     3954 non-null object
# PetID           3972 non-null object
# PhotoAmt        3972 non-null int64
# dtypes: int64(19), object(4)
# memory usage: 713.8+ KB

# %% [markdown]
# Notice that there are null values for description (1), and several for Name, which is to be expected based on the cleaning done prior to importing data sets.
#
# There are _not_ null values for breed, which is unexpected, as some pets should be only one breed vs a mixed breed (values in Breed1 and Breed2).

# %%
#Examine Train Data Set
train_data.head()
# Out:
#    Type         Name  Age  Breed1  Breed2  Gender  Color1  Color2  Color3  \
# 0     2       Nibble    3     299       0       1       1       7       0
# 1     2  No Name Yet    1     265       0       1       1       2       0
# 2     1       Brisco    1     307       0       1       2       7       0
# 3     1         Miko    4     307       0       2       1       2       0
# 4     1       Hunter    1     307       0       1       1       0       0
#
#    MaturitySize  ...  Health  Quantity  Fee  State  \
# 0             1  ...       1         1  100  41326
# 1             2  ...       1         1    0  41401
# 2             2  ...       1         1    0  41326
# 3             2  ...       1         1  150  41401
# 4             2  ...       1         1    0  41326
#
#                           RescuerID  VideoAmt  \
# 0  8480853f516546f6cf33aa88cd76c379         0
# 1  3082c7125d8fb66f7dd4bff4192c8b14         0
# 2  fa90fa5b1ee11c86938398b60abc32cb         0
# 3  9238e4f44c71a75282e62f7136c6b240         0
# 4  95481e953f8aed9ec3d16fc4509537e8         0
#
#                                          Description      PetID PhotoAmt  \
# 0  Nibble is a 3+ month old ball of cuteness. He ...  86e1089a3        1
# 1  I just found it alone yesterday near my apartm...  6296e909a        2
# 2  Their pregnant mother was dumped by her irresp...  3422e4906        7
# 3  Good guard dog, very alert, active, obedience ...  5842f1ff5        8
# 4  This handsome yet cute boy is up for adoption....  850a43f90        3
#
#    AdoptionSpeed
# 0              2
# 1              0
# 2              3
# 3              2
# 4              2
#
# [5 rows x 24 columns]

# %%
train_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14991 entries, 0 to 14990
# Data columns (total 24 columns):
# Type             14991 non-null int64
# Name             12020 non-null object
# Age              14991 non-null int64
# Breed1           14991 non-null int64
# Breed2           14991 non-null int64
# Gender           14991 non-null int64
# Color1           14991 non-null int64
# Color2           14991 non-null int64
# Color3           14991 non-null int64
# MaturitySize     14991 non-null int64
# FurLength        14991 non-null int64
# Vaccinated       14991 non-null int64
# Dewormed         14991 non-null int64
# Sterilized       14991 non-null int64
# Health           14991 non-null int64
# Quantity         14991 non-null int64
# Fee              14991 non-null int64
# State            14991 non-null int64
# RescuerID        14991 non-null object
# VideoAmt         14991 non-null int64
# Description      14922 non-null object
# PetID            14991 non-null object
# PhotoAmt         14991 non-null int64
# AdoptionSpeed    14991 non-null int64
# dtypes: int64(20), object(4)
# memory usage: 2.7+ MB

# %% [markdown]
# Notice that there are again null values in description and name, but no null values in the breed column.

# %%
#Combine Data sets

#Add blank 'Adoption Speed' column to test
test_data['AdoptionSpeed']=''

#Combine Data Sets
data=pd.concat([test_data,train_data],axis=0).reset_index()
data.head()
# Out:
#    index  Type                       Name  Age  Breed1  Breed2  Gender  \
# 0      0     2               Dopey & Grey    8     266     266       1
# 1      1     2                    Chi Chi   36     285     264       2
# 2      2     2                     Sticky    2     265       0       1
# 3      3     1  Dannie & Kass [In Penang]   12     307       0       2
# 4      4     2                    Cuddles   12     265       0       1
#
#    Color1  Color2  Color3  ...  Health  Quantity  Fee  State  \
# 0       2       6       7  ...       1         2    0  41326
# 1       1       4       7  ...       2         1    0  41326
# 2       6       7       0  ...       1         1  200  41326
# 3       2       5       0  ...       1         2    0  41326
# 4       2       3       7  ...       1         1    0  41326
#
#                           RescuerID  VideoAmt  \
# 0  2ece3b2573dcdcebd774e635dca15fd9         0
# 1  2ece3b2573dcdcebd774e635dca15fd9         0
# 2  e59c106e9912fa30c898976278c2e834         0
# 3  e59c106e9912fa30c898976278c2e834         0
# 4  e59c106e9912fa30c898976278c2e834         0
#
#                                          Description      PetID  PhotoAmt  \
# 0  Dopey Age: 8mths old Male One half of a pair, ...  e2dfc2935         2
# 1  Please note that Chichi has been neutered, the...  f153b465f         1
# 2  Sticky, named such because of his tendency to ...  3c90f3f54         4
# 3  Dannie and Kass are mother and daughter. We en...  e02abc8a3         5
# 4  Extremely cuddly cat, hence the origin of his ...  09f0df7d1         5
#
#   AdoptionSpeed
# 0
# 1
# 2
# 3
# 4
#
# [5 rows x 25 columns]

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18963 entries, 0 to 18962
# Data columns (total 25 columns):
# index            18963 non-null int64
# Type             18963 non-null int64
# Name             15169 non-null object
# Age              18963 non-null int64
# Breed1           18963 non-null int64
# Breed2           18963 non-null int64
# Gender           18963 non-null int64
# Color1           18963 non-null int64
# Color2           18963 non-null int64
# Color3           18963 non-null int64
# MaturitySize     18963 non-null int64
# FurLength        18963 non-null int64
# Vaccinated       18963 non-null int64
# Dewormed         18963 non-null int64
# Sterilized       18963 non-null int64
# Health           18963 non-null int64
# Quantity         18963 non-null int64
# Fee              18963 non-null int64
# State            18963 non-null int64
# RescuerID        18963 non-null object
# VideoAmt         18963 non-null int64
# Description      18876 non-null object
# PetID            18963 non-null object
# PhotoAmt         18963 non-null int64
# AdoptionSpeed    18963 non-null object
# dtypes: int64(20), object(5)
# memory usage: 3.6+ MB

# %% [markdown]
# For the purposes of this problem, we're only interested in dog-specific information. So let's pull only the data related to dogs from each of the files. In this case dogs are pet type 1.

# %%
dog_breeds = breeds[breeds.Type==1]
dog_data = data[data.Type==1]

# %% [markdown]
# Reinvestigate the dataframes without the cats in them.

# %%
dog_breeds.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 241 entries, 0 to 240
# Data columns (total 3 columns):
# BreedID      241 non-null int64
# Type         241 non-null int64
# BreedName    241 non-null object
# dtypes: int64(2), object(1)
# memory usage: 7.5+ KB

# %%
dog_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 10230 entries, 3 to 18962
# Data columns (total 25 columns):
# index            10230 non-null int64
# Type             10230 non-null int64
# Name             7238 non-null object
# Age              10230 non-null int64
# Breed1           10230 non-null int64
# Breed2           10230 non-null int64
# Gender           10230 non-null int64
# Color1           10230 non-null int64
# Color2           10230 non-null int64
# Color3           10230 non-null int64
# MaturitySize     10230 non-null int64
# FurLength        10230 non-null int64
# Vaccinated       10230 non-null int64
# Dewormed         10230 non-null int64
# Sterilized       10230 non-null int64
# Health           10230 non-null int64
# Quantity         10230 non-null int64
# Fee              10230 non-null int64
# State            10230 non-null int64
# RescuerID        10230 non-null object
# VideoAmt         10230 non-null int64
# Description      10196 non-null object
# PetID            10230 non-null object
# PhotoAmt         10230 non-null int64
# AdoptionSpeed    10230 non-null object
# dtypes: int64(20), object(5)
# memory usage: 2.0+ MB

# %% [markdown]
# We no longer need the type columns, so let's go ahead and drop them to save memory.

# %%
dog_breeds = dog_breeds.drop(['Type'] , axis = 1)
dog_data = dog_data.drop(['Type'] , axis =1)

# %%
#Investigate Null Description Rows
no_descrip=dog_data[dog_data.Description.isnull()]
no_descrip
# Out:
#        index                      Name  Age  Breed1  Breed2  Gender  Color1  \
# 488      488                   Pat Pat    3     307     307       2       5
# 3009    3009                       NaN    1     207       0       2       1
# 3010    3010  Pure Breed Silky Terrier    1     207       0       2       1
# 3011    3011                       NaN    1     207       0       2       1
# 4011      39                       NaN   12     307       0       1       5
# 4330     358                     DIANA   18     307     307       2       1
# 4408     436                       NaN    1     307       0       3       1
# 4964     992                    Tennis   10     109       0       1       5
# 5541    1569                       NaN    1     307       0       2       1
# 5573    1601                       NaN   24     179       0       2       2
# 6081    2109      Chelsea And Sherbert   31     307       0       2       1
# 8188    4216                      OWEN   48     307     307       1       2
# 9403    5431                     ETHAN   10     307     307       1       4
# 9778    5806                       NaN    1     307       0       2       1
# 10093   6121                  Xiao Dao   16     307       0       2       1
# 10584   6612                    ROLAND   12     307     307       1       1
# 11374   7402               BiBi & GiGi   12     307     307       3       2
# 11511   7539                      Emma    8     307     307       2       6
# 11541   7569                   MICHEAL    5     307     307       1       7
# 11599   7627                    Snowie   35     109     141       2       3
# 11666   7694                      Tony   24     307       0       1       2
# 12219   8247                       NaN    0     307     307       3       1
# 12313   8341                       NaN    1     307       0       1       1
# 12440   8468                    MANSON   36     189     307       1       1
# 12467   8495                       NaN    2     307     307       2       1
# 13689   9717                       NaN    4     307     307       2       1
# 14024  10052                      Bebe   48     307       0       2       1
# 14223  10251                     HAPPY   48     307     307       2       1
# 14243  10271                       NaN    0     307       0       1       5
# 14267  10295                       NaN   24     307       0       2       7
# 16683  12711                       Ben    7     109       0       1       3
# 17234  13262                     MISON   39     307     307       2       2
# 17258  13286                    Mickey    9     147     195       1       7
# 18707  14735                      ADAM   10     307     307       1       1
#
#        Color2  Color3  MaturitySize  ...  Health  Quantity  Fee  State  \
# 488         0       0             2  ...       1         1    0  41332
# 3009        2       0             1  ...       1         1  700  41326
# 3010        2       0             1  ...       1         1  700  41326
# 3011        2       0             1  ...       1         1  700  41326
# 4011        0       0             2  ...       1         1    0  41326
# 4330        0       0             2  ...       1         1    0  41326
# 4408        2       7             2  ...       1         5    0  41326
# 4964        0       0             3  ...       1         1    0  41401
# 5541        2       0             1  ...       1         1    0  41401
# 5573        0       0             1  ...       1         1    0  41326
# 6081        2       7             2  ...       1         2    0  41401
# 8188        0       0             2  ...       1         1    0  41326
# 9403        7       0             3  ...       1         1    0  41326
# 9778        7       0             1  ...       1         1    0  41401
# 10093       2       7             2  ...       1         1    0  41336
# 10584       2       0             2  ...       1         1    0  41326
# 11374       7       0             2  ...       1         2    0  41401
# 11511       0       0             2  ...       1         1    0  41326
# 11541       0       0             2  ...       1         1    0  41326
# 11599       0       0             2  ...       1         1   50  41336
# 11666       7       0             2  ...       2         1    0  41401
# 12219       2       7             1  ...       3         5    0  41401
# 12313       0       0             1  ...       1         1    0  41401
# 12440       2       0             3  ...       1         1    0  41326
# 12467       2       3             2  ...       1         1    0  41401
# 13689       2       7             2  ...       1         2    0  41326
# 14024       5       7             2  ...       1         1    0  41401
# 14223       7       0             2  ...       1         1    0  41326
# 14243       7       0             2  ...       2         1    0  41326
# 14267       0       0             2  ...       1         1    0  41330
# 16683       0       0             3  ...       1         1  250  41326
# 17234       0       0             2  ...       1         1    0  41326
# 17258       0       0             1  ...       1         1    0  41401
# 18707       2       0             3  ...       1         1    0  41326
#
#                               RescuerID  VideoAmt  Description      PetID  \
# 488    88d48aeb402a9d6a891fff5c0b86a29a         0          NaN  1f85c9142
# 3009   723d408dd3017416249d388b8232decb         0          NaN  944c4186b
# 3010   723d408dd3017416249d388b8232decb         0          NaN  58af3154a
# 3011   723d408dd3017416249d388b8232decb         0          NaN  17656ed15
# 4011   6757d0b9d5b72d8b78c20e355c7fe62c         0          NaN  4e3640544
# 4330   13733222f015ec6a0017c3c0527738ff         0          NaN  3a3ae56f1
# 4408   eee77f12979856ef498630954461b4e3         0          NaN  1a9e7158e
# 4964   7abebb25ee29f6d01a5fdae400cfbbab         0          NaN  06bf9e676
# 5541   8bb437e94e4664422536b5c3ce3682af         0          NaN  92bf4bb1a
# 5573   239b99bbff682c0bc548ce9ccbc1182c         0          NaN  f6ae0d580
# 6081   c814d8b7928da23e3add9ec4d270de95         0          NaN  50eddd1bb
# 8188   13733222f015ec6a0017c3c0527738ff         0          NaN  08267e916
# 9403   13733222f015ec6a0017c3c0527738ff         0          NaN  79799da25
# 9778   8bb437e94e4664422536b5c3ce3682af         0          NaN  983160271
# 10093  d73b10f170720b7edc3c12fc93b1fc63         0          NaN  11ce5617d
# 10584  13733222f015ec6a0017c3c0527738ff         0          NaN  d0eb1073d
# 11374  ce49caa9e83b34c4d4c7d36a6d5d6659         0          NaN  113204c87
# 11511  13733222f015ec6a0017c3c0527738ff         0          NaN  74b73209e
# 11541  13733222f015ec6a0017c3c0527738ff         0          NaN  00bfa5da9
# 11599  4436950a0688eb8e376bc00845099e19         0          NaN  a8cfbf446
# 11666  9238e4f44c71a75282e62f7136c6b240         0          NaN  21cc6a743
# 12219  1dcae1d6d72c3fa738f5569bf30b27e9         0          NaN  3948f67d7
# 12313  8bb437e94e4664422536b5c3ce3682af         0          NaN  49a832741
# 12440  13733222f015ec6a0017c3c0527738ff         0          NaN  9e6570928
# 12467  78ec79634d350f6850fdd4a335cab431         0          NaN  f60779a3b
# 13689  13733222f015ec6a0017c3c0527738ff         0          NaN  ca121ab91
# 14024  9238e4f44c71a75282e62f7136c6b240         0          NaN  060d1de98
# 14223  13733222f015ec6a0017c3c0527738ff         0          NaN  9ca5f1891
# 14243  f0997d267a9acadd44a5301a18f83df5         0          NaN  f67786a70
# 14267  994fadc56839adcf9a104673e6160dee         0          NaN  afc71f432
# 16683  64c0b95d07c9e6d3ea11f801abf69104         0          NaN  453750088
# 17234  13733222f015ec6a0017c3c0527738ff         0          NaN  0fd5ff08e
# 17258  ea30ea2ffa4da118e588611f71f7f727         0          NaN  fac19639c
# 18707  13733222f015ec6a0017c3c0527738ff         0          NaN  c46e29741
#
#       PhotoAmt  AdoptionSpeed
# 488          1
# 3009         3
# 3010         8
# 3011         3
# 4011         1              3
# 4330         3              4
# 4408        15              1
# 4964         1              1
# 5541         1              2
# 5573         1              1
# 6081         3              2
# 8188         3              4
# 9403         2              4
# 9778         1              2
# 10093        5              3
# 10584        1              4
# 11374        1              4
# 11511        4              3
# 11541        2              4
# 11599        2              2
# 11666        5              3
# 12219       10              3
# 12313        1              2
# 12440        4              4
# 12467        5              2
# 13689        1              3
# 14024        5              4
# 14223        3              4
# 14243        0              4
# 14267        4              4
# 16683        4              1
# 17234        3              4
# 17258        1              1
# 18707        4              4
#
# [34 rows x 24 columns]

# %% [markdown]
# All data appears to be intact, so a lack of description unlikely to be an indicator of missing or bad data.
# Leave missing descriptions as null values. No additional cleaning is necessary knowing description data was cleaned prior to import.
#
# However, notice that one of the animals (#488) has no value for adoption speed, despite there being no null values... this will need investigated in a moment.

# %%
#From data investigation we know some of the breed's are zero, is zero in the breeds table?
dog_breeds.head()
# Out:
#    BreedID         BreedName
# 0        1     Affenpinscher
# 1        2      Afghan Hound
# 2        3  Airedale Terrier
# 3        4            Akbash
# 4        5             Akita

# %% [markdown]
# There is no breed ID of zero, however we may be merging the breed, color, and state tables with the data set so let's create a breed table with a response for a BreedID of zero.

# %%
#Create value for if there is no breed
index_none=['BreedID','BreedName']
nobreed=pd.DataFrame([0,np.NaN],index=index_none)
nobreed=nobreed.T

#Append value if no breed to breeds table
dog_breeds_wnone=nobreed.append(dog_breeds,sort=True)
dog_breeds_wnone.head()
# Out:
#    BreedID         BreedName
# 0      0.0               NaN
# 0      1.0     Affenpinscher
# 1      2.0      Afghan Hound
# 2      3.0  Airedale Terrier
# 3      4.0            Akbash

# %% [markdown]
# Save data frame as csv for use later

# %%
dog_breeds_wnone.to_csv(r'tidy_data/dog_breeds.csv')

# %% [markdown]
# It may be important to know if an animal is a mixed breed or not.... so let's create a column to identify mixed vs "pure" breed animals.

# %%
dog_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 10230 entries, 3 to 18962
# Data columns (total 24 columns):
# index            10230 non-null int64
# Name             7238 non-null object
# Age              10230 non-null int64
# Breed1           10230 non-null int64
# Breed2           10230 non-null int64
# Gender           10230 non-null int64
# Color1           10230 non-null int64
# Color2           10230 non-null int64
# Color3           10230 non-null int64
# MaturitySize     10230 non-null int64
# FurLength        10230 non-null int64
# Vaccinated       10230 non-null int64
# Dewormed         10230 non-null int64
# Sterilized       10230 non-null int64
# Health           10230 non-null int64
# Quantity         10230 non-null int64
# Fee              10230 non-null int64
# State            10230 non-null int64
# RescuerID        10230 non-null object
# VideoAmt         10230 non-null int64
# Description      10196 non-null object
# PetID            10230 non-null object
# PhotoAmt         10230 non-null int64
# AdoptionSpeed    10230 non-null object
# dtypes: int64(19), object(5)
# memory usage: 2.0+ MB

# %%
#Create a new column 'MixedBreed' and insert it after "Breed2"

#Initalize an empty list
breed_count=[]

for index in dog_data.index:
    #Reset variable a
    a=0
    
    #If both defined breeds are the same, there is 1 breed
    if (dog_data['Breed1'][index] == dog_data['Breed2'][index]):
        a+= 1
    
    #If either defined breed is "0", or no breed, there is 1 breed
    elif (dog_data['Breed1'][index] == 0) or (dog_data['Breed2'][index] == 0):
        a += 1
   
    #If neither of the above, the dog is mixed breed, and so there are 2
    else:
        a += 2
    breed_count.append(a)

#Find index of Breed 2 position and add 1 to define position for new column
mixed_posn = dog_data.columns.get_loc('Breed2') + 1

#Insert calculated values as new column
dog_data.insert(mixed_posn, "BreedCount" , breed_count)

#Check counts
dog_data.head()
# Out:
#     index                       Name  Age  Breed1  Breed2  BreedCount  Gender  \
# 3       3  Dannie & Kass [In Penang]   12     307       0           1       2
# 9       9                   Precious   36      76     307           2       2
# 10     10                      Angel   24     307     307           1       2
# 11     11                        NaN   12     307     307           1       2
# 12     12                        NaN    3     218     307           2       1
#
#     Color1  Color2  Color3  ...  Health  Quantity  Fee  State  \
# 3        2       5       0  ...       1         2    0  41326
# 9        7       0       0  ...       1         1    0  41324
# 10       5       7       0  ...       1         1    0  41324
# 11       2       3       0  ...       1         2    0  41324
# 12       1       7       0  ...       1         1    0  41324
#
#                            RescuerID  VideoAmt  \
# 3   e59c106e9912fa30c898976278c2e834         0
# 9   6f73a23fdb52bc9a30dc788fe6ccc7f6         0
# 10  6f73a23fdb52bc9a30dc788fe6ccc7f6         0
# 11  6f73a23fdb52bc9a30dc788fe6ccc7f6         0
# 12  6f73a23fdb52bc9a30dc788fe6ccc7f6         1
#
#                                           Description      PetID  PhotoAmt  \
# 3   Dannie and Kass are mother and daughter. We en...  e02abc8a3         5
# 9   Hi, i have a dalmamation mix female dog to giv...  a3787f15e         9
# 10  found a stray female dog who follows my mum ca...  0113cedff         3
# 11  both female dogs r thrown away at d food court...  0070b950a         4
# 12  Hi, im liew here.. Im not sure how is this don...  cbe2df167         0
#
#    AdoptionSpeed
# 3
# 9
# 10
# 11
# 12
#
# [5 rows x 25 columns]

# %% [markdown]
# Let's go back and investigate blank adoption values. First, what value is assigned, since the values are non-null.

# %%
#Fix missing adoption values
print(dog_data.AdoptionSpeed.unique())
# Out:
# ['' 3 2 1 4 0]

# %% [markdown]
# It looks like the source of missing adoption speeds is from the 'test' data set.
#
# For the purposes of exploration, let's assign make the missing values nulls.

# %%
dog_data.AdoptionSpeed = dog_data.AdoptionSpeed.replace('',np.nan)

# %% [markdown]
# Notice that there are multiple zero values in the color columns.Let's repeat the same steps done for breeds and add a zero column to the color table, which would assign null values for 0 color.

# %%
#Create value for if there is no color
index_none=['ColorID','ColorName']
nocolor=pd.DataFrame([0,np.NaN],index=index_none)
nocolor=nocolor.T

#Append value if no color to color table
colors_wnone=nocolor.append(color,sort=True)
colors_wnone
# Out:
#    ColorID ColorName
# 0      0.0       NaN
# 0      1.0     Black
# 1      2.0     Brown
# 2      3.0    Golden
# 3      4.0    Yellow
# 4      5.0     Cream
# 5      6.0      Gray
# 6      7.0     White

# %% [markdown]
# Save the modified colors table to a new csv file for later use

# %%
colors_wnone.to_csv(r'tidy_data/dog_colors.csv')

# %% [markdown]
# Now, we're going to need some data frames to allow us to "decode" the values for the other categorical variables, MaturitySize, FurLength, Vaccinated, Dewormed, Sterilized, and Health.
#
# Some investigation shows the following to correspond to the numerical values:
#
# MaturitySize -
#     - Size at maturity
#     - 1 = Small, 2 = Medium, 3 = Large, 4 = Extra Large, 0 = Not Specified
# FurLength -
#     - Fur length
#     - 1 = Short, 2 = Medium, 3 = Long, 0 = Not Specified
# Vaccinated -
#     - Pet has been vaccinated
#     - 1 = Yes, 2 = No, 3 = Not Sure
# Dewormed -
#     -  Pet has been dewormed
#     - 1 = Yes, 2 = No, 3 = Not Sure
# Sterilized -
#     - Pet has been spayed / neutered
#     - 1 = Yes, 2 = No, 3 = Not Sure
# Health - Health Condition
#     - 1 = Healthy, 2 = Minor Injury, 3 = Serious Injury, 0 = Not Specified
#
# Adoption Speed
#     - 0 = Same day Adoption
#     - 1 = Pet was adopted between 1-7 days (1 week)
#     - 2 = Pet was adopted between 8-30 days (1 month)
#     - 3 = Pet was adopted between 31-90 days (2-3 months)
#     - 4 = Pet was not adopted
#
#
# Let's define data frames and save them as csv files in case we need them later.

# %%
#MaturitySize - 
size= {'Size': ['Small','Medium','Large','Giant','Unknown'],
        'SizeValue': [1,2,3,4,0]}
size=pd.DataFrame.from_dict(size)
size.to_csv(r'tidy_data/size.csv',index=False)
size
# Out:
#       Size  SizeValue
# 0    Small          1
# 1   Medium          2
# 2    Large          3
# 3    Giant          4
# 4  Unknown          0

# %%
#Fur Length - 
fur_length= {'Length': ['Short','Medium','Long','Unknown'],
        'LengthValue': [1,2,3,0]}
fur_length=pd.DataFrame.from_dict(fur_length)
fur_length.to_csv(r'tidy_data/fur_length.csv',index=False)

fur_length
# Out:
#     Length  LengthValue
# 0    Short            1
# 1   Medium            2
# 2     Long            3
# 3  Unknown            0

# %%
#Vaccinated - 
vaccine= {'VaccineStatus': ['Vaccinated','Not Vaccinated','Unknown'],
        'VaccineValue': [1,2,3]}
vaccine=pd.DataFrame.from_dict(vaccine)
vaccine.to_csv(r'tidy_data/vaccine.csv',index=False)

vaccine
# Out:
#     VaccineStatus  VaccineValue
# 0      Vaccinated             1
# 1  Not Vaccinated             2
# 2         Unknown             3

# %%
#Vaccinated - 
dewormed= {'DewormStatus': ['Dewormed','Not Dewormed','Unknown'],
        'DewormValue': [1,2,3]}
dewormed=pd.DataFrame.from_dict(dewormed)
dewormed.to_csv(r'tidy_data/dewormed.csv',index=False)

dewormed
# Out:
#    DewormStatus  DewormValue
# 0      Dewormed            1
# 1  Not Dewormed            2
# 2       Unknown            3

# %%
#Sterilized - 
sterilized= {'FixStatus': ['Fixed','Not Fixed','Unknown'],
        'FixValue': [1,2,3]}
sterilized=pd.DataFrame.from_dict(sterilized)
sterilized.to_csv(r'tidy_data/sterilized.csv',index=False)

sterilized
# Out:
#    FixStatus  FixValue
# 0      Fixed         1
# 1  Not Fixed         2
# 2    Unknown         3

# %%
#Health- 
health= {'HealthStatus': ['Healthy','Minor Injury','Serious Injury','Unknown'],
        'HealthValue': [1,2,3,0]}
health=pd.DataFrame.from_dict(health)
health.to_csv(r'tidy_data/health.csv',index=False)

health
# Out:
#      HealthStatus  HealthValue
# 0         Healthy            1
# 1    Minor Injury            2
# 2  Serious Injury            3
# 3         Unknown            0

# %%
#Adoption Speed

adpt= {'AdoptionSpeed': ['0','1-7','8-30','31-90','Unadopted'],
        'AdoptionValue': [0,1,2,3,4]}
adpt=pd.DataFrame.from_dict(adpt)
adpt.to_csv(r'tidy_data/adoption_speed.csv',index=False)

adpt
# Out:
#   AdoptionSpeed  AdoptionValue
# 0             0              0
# 1           1-7              1
# 2          8-30              2
# 3         31-90              3
# 4     Unadopted              4

# %% [markdown]
# The data looks nicely tidied!
#
# Now let's reset the index, and save the tidied up dog information to its own csv file for use later.

# %%
#Drop the existing index column 
dd = dog_data.iloc[:,1:]
dd.reset_index(inplace=True)
dd.head()
# Out:
#    index                       Name  Age  Breed1  Breed2  BreedCount  Gender  \
# 0      3  Dannie & Kass [In Penang]   12     307       0           1       2
# 1      9                   Precious   36      76     307           2       2
# 2     10                      Angel   24     307     307           1       2
# 3     11                        NaN   12     307     307           1       2
# 4     12                        NaN    3     218     307           2       1
#
#    Color1  Color2  Color3  ...  Health  Quantity  Fee  State  \
# 0       2       5       0  ...       1         2    0  41326
# 1       7       0       0  ...       1         1    0  41324
# 2       5       7       0  ...       1         1    0  41324
# 3       2       3       0  ...       1         2    0  41324
# 4       1       7       0  ...       1         1    0  41324
#
#                           RescuerID  VideoAmt  \
# 0  e59c106e9912fa30c898976278c2e834         0
# 1  6f73a23fdb52bc9a30dc788fe6ccc7f6         0
# 2  6f73a23fdb52bc9a30dc788fe6ccc7f6         0
# 3  6f73a23fdb52bc9a30dc788fe6ccc7f6         0
# 4  6f73a23fdb52bc9a30dc788fe6ccc7f6         1
#
#                                          Description      PetID  PhotoAmt  \
# 0  Dannie and Kass are mother and daughter. We en...  e02abc8a3         5
# 1  Hi, i have a dalmamation mix female dog to giv...  a3787f15e         9
# 2  found a stray female dog who follows my mum ca...  0113cedff         3
# 3  both female dogs r thrown away at d food court...  0070b950a         4
# 4  Hi, im liew here.. Im not sure how is this don...  cbe2df167         0
#
#   AdoptionSpeed
# 0           NaN
# 1           NaN
# 2           NaN
# 3           NaN
# 4           NaN
#
# [5 rows x 25 columns]

# %%
#Drop and replace the newly created index column 
dd2 = dd.iloc[:,1:]
dd2.reset_index(inplace=True)
dd2.head()
# Out:
#    index                       Name  Age  Breed1  Breed2  BreedCount  Gender  \
# 0      0  Dannie & Kass [In Penang]   12     307       0           1       2
# 1      1                   Precious   36      76     307           2       2
# 2      2                      Angel   24     307     307           1       2
# 3      3                        NaN   12     307     307           1       2
# 4      4                        NaN    3     218     307           2       1
#
#    Color1  Color2  Color3  ...  Health  Quantity  Fee  State  \
# 0       2       5       0  ...       1         2    0  41326
# 1       7       0       0  ...       1         1    0  41324
# 2       5       7       0  ...       1         1    0  41324
# 3       2       3       0  ...       1         2    0  41324
# 4       1       7       0  ...       1         1    0  41324
#
#                           RescuerID  VideoAmt  \
# 0  e59c106e9912fa30c898976278c2e834         0
# 1  6f73a23fdb52bc9a30dc788fe6ccc7f6         0
# 2  6f73a23fdb52bc9a30dc788fe6ccc7f6         0
# 3  6f73a23fdb52bc9a30dc788fe6ccc7f6         0
# 4  6f73a23fdb52bc9a30dc788fe6ccc7f6         1
#
#                                          Description      PetID  PhotoAmt  \
# 0  Dannie and Kass are mother and daughter. We en...  e02abc8a3         5
# 1  Hi, i have a dalmamation mix female dog to giv...  a3787f15e         9
# 2  found a stray female dog who follows my mum ca...  0113cedff         3
# 3  both female dogs r thrown away at d food court...  0070b950a         4
# 4  Hi, im liew here.. Im not sure how is this don...  cbe2df167         0
#
#   AdoptionSpeed
# 0           NaN
# 1           NaN
# 2           NaN
# 3           NaN
# 4           NaN
#
# [5 rows x 25 columns]

# %%
#Save the cleaned data to a csv
dd2.to_csv(r'tidy_data/dog_data.csv',index=False)

# %% [markdown]
# Let's now import the dataset specific to the shelter.
#
# The data was pulled via the API and the steps performed can be seen in the the notebook found here: [Github Link](https://github.com/CJEJansson/Springboard_Projects/blob/master/Capstone%201/Data_Wrangling/BigBones%20API%20Pull.ipynb)

# %%
shelter_dogs=pd.read_csv('BigBonesDoggos.csv')
shelter_dogs.head()
# Out:
#    Unnamed: 0 organization_id  animal_id animal_type    age  \
# 0           0           co441   46224186         dog   Baby
# 1           1           co441   46224166         dog  Adult
# 2           2           co441   46224128         dog  Adult
# 3           3           co441   46224152         dog  Adult
# 4           4           co441   46201468         dog  Adult
#
#    attributes.declawed  attributes.house_trained  attributes.shots_current  \
# 0                  NaN                      True                      True
# 1                  NaN                      True                      True
# 2                  NaN                      True                      True
# 3                  NaN                      True                      True
# 4                  NaN                      True                      True
#
#    attributes.spayed_neutered  attributes.special_needs  ...  \
# 0                        True                     False  ...
# 1                        True                     False  ...
# 2                        True                     False  ...
# 3                        True                     False  ...
# 4                        True                     False  ...
#
#    organization_id.1                                             photos  \
# 0              CO441  [{'small': 'https://dl5zpyw5k3jeb.cloudfront.n...
# 1              CO441  [{'small': 'https://dl5zpyw5k3jeb.cloudfront.n...
# 2              CO441  [{'small': 'https://dl5zpyw5k3jeb.cloudfront.n...
# 3              CO441  [{'small': 'https://dl5zpyw5k3jeb.cloudfront.n...
# 4              CO441  [{'small': 'https://dl5zpyw5k3jeb.cloudfront.n...
#
#                published_at    size species     status  \
# 0  2019-10-09T17:32:46+0000   Small     Dog  adoptable
# 1  2019-10-09T17:31:22+0000   Large     Dog  adoptable
# 2  2019-10-09T17:30:14+0000   Large     Dog  adoptable
# 3  2019-10-09T17:29:33+0000   Large     Dog  adoptable
# 4  2019-10-07T15:21:31+0000  Medium     Dog  adoptable
#
#           status_changed_at  tags  type  \
# 0  2019-10-09T17:32:46+0000    []   Dog
# 1  2019-10-09T17:31:22+0000    []   Dog
# 2  2019-10-09T17:30:14+0000    []   Dog
# 3  2019-10-09T17:29:33+0000    []   Dog
# 4  2019-10-07T15:21:31+0000    []   Dog
#
#                                                  url
# 0  https://www.petfinder.com/dog/tiko-46224186/co...
# 1  https://www.petfinder.com/dog/brody-46224166/c...
# 2  https://www.petfinder.com/dog/cooper-46224128/...
# 3  https://www.petfinder.com/dog/emmy-46224152/co...
# 4  https://www.petfinder.com/dog/ittie-bit-462014...
#
# [5 rows x 44 columns]

# %%
#Remove empty columns. Replace later if data is obtained. 
#drops=[]
shelter_dogs=shelter_dogs.drop(['organization_id','attributes.declawed', 'coat', \
       'colors.primary','colors.secondary', 'colors.tertiary', 'contact.address.address1', \
       'contact.address.address2'],axis=1)
shelter_dogs.head()
# Out:
#    Unnamed: 0  animal_id animal_type    age  attributes.house_trained  \
# 0           0   46224186         dog   Baby                      True
# 1           1   46224166         dog  Adult                      True
# 2           2   46224128         dog  Adult                      True
# 3           3   46224152         dog  Adult                      True
# 4           4   46201468         dog  Adult                      True
#
#    attributes.shots_current  attributes.spayed_neutered  \
# 0                      True                        True
# 1                      True                        True
# 2                      True                        True
# 3                      True                        True
# 4                      True                        True
#
#    attributes.special_needs  breeds.mixed   breeds.primary  ...  \
# 0                     False          True        Chihuahua  ...
# 1                     False          True  English Bulldog  ...
# 2                     False          True         Shepherd  ...
# 3                     False          True  English Bulldog  ...
# 4                     False          True           Beagle  ...
#
#   organization_id.1                                             photos  \
# 0             CO441  [{'small': 'https://dl5zpyw5k3jeb.cloudfront.n...
# 1             CO441  [{'small': 'https://dl5zpyw5k3jeb.cloudfront.n...
# 2             CO441  [{'small': 'https://dl5zpyw5k3jeb.cloudfront.n...
# 3             CO441  [{'small': 'https://dl5zpyw5k3jeb.cloudfront.n...
# 4             CO441  [{'small': 'https://dl5zpyw5k3jeb.cloudfront.n...
#
#                published_at    size  species     status  \
# 0  2019-10-09T17:32:46+0000   Small      Dog  adoptable
# 1  2019-10-09T17:31:22+0000   Large      Dog  adoptable
# 2  2019-10-09T17:30:14+0000   Large      Dog  adoptable
# 3  2019-10-09T17:29:33+0000   Large      Dog  adoptable
# 4  2019-10-07T15:21:31+0000  Medium      Dog  adoptable
#
#           status_changed_at tags type  \
# 0  2019-10-09T17:32:46+0000   []  Dog
# 1  2019-10-09T17:31:22+0000   []  Dog
# 2  2019-10-09T17:30:14+0000   []  Dog
# 3  2019-10-09T17:29:33+0000   []  Dog
# 4  2019-10-07T15:21:31+0000   []  Dog
#
#                                                  url
# 0  https://www.petfinder.com/dog/tiko-46224186/co...
# 1  https://www.petfinder.com/dog/brody-46224166/c...
# 2  https://www.petfinder.com/dog/cooper-46224128/...
# 3  https://www.petfinder.com/dog/emmy-46224152/co...
# 4  https://www.petfinder.com/dog/ittie-bit-462014...
#
# [5 rows x 36 columns]

# %% [markdown]
# Doesn't look like the data will align very nicely. May be easier to contact the shelter and see if they track their data directly. Even if we're unable to study their data set, we can make recommendations based on what we find studying the petfinder data.
